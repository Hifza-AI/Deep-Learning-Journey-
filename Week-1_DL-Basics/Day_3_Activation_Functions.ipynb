# %%
import numpy as np 
inputs = np.array([23, 67, 58])
weights = np.array([
    [20, 60, 25],
    [15, 35, 50]
])
biases = np.array([4, 6])
layer_Outputs = np. dot(weights, inputs ) + biases
print(f"Outputs of both neurons:", layer_Outputs)
# Out:
# Outputs of both neurons: [5934 5596]

# %%
import numpy as np

# Inputs (Data)
inputs = np.array([10, 20]) 

# Weights (Importance) - Inhein badal kar dekho!
weights = np.array([2, -0.2]) 

# Bias
bias = 78

# Result
output = np.dot(inputs, weights) + bias
print(f"Final Output: {output}")
# Out:
# Final Output: 94.0

# %%
import os
import shutil
from kaggle_secrets import UserSecretsClient

# 1. Fresh Secrets
user_secrets = UserSecretsClient()
token = user_secrets.get_secret("GITHUB_TOKEN")
username = user_secrets.get_secret("GITHUB_USERNAME")
repo_name = "Deep-Learning-Journey-" 

# 2. Cleanup (Purana kachra saaf)
if os.path.exists(repo_name):
    shutil.rmtree(repo_name)

# 3. Fresh Clone & Push
repo_url = f"https://{username}:{token}@github.com/{username}/{repo_name}.git"
# !git clone {repo_url}
# %cd {repo_name}

# Notebook file ko sahi naam se copy karna
# !cp /kaggle/working/notebook.ipynb ./Day_2_Neural_Network.ipynb

# !git add .
# !git commit -m "Day 2: Final Success Upload 🚀"
# !git push
# Out:
# Cloning into 'Deep-Learning-Journey-'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 5 (delta 0), reused 2 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (5/5), done.
# /kaggle/working/Deep-Learning-Journey-
# cp: cannot stat '/kaggle/working/notebook.ipynb': No such file or directory
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@226d895e9f98.(none)')
# Everything up-to-date

# %%
import os
import shutil
from kaggle_secrets import UserSecretsClient

# 1. Setup
user_secrets = UserSecretsClient()
token = user_secrets.get_secret("GITHUB_TOKEN")
username = user_secrets.get_secret("GITHUB_USERNAME")
repo_name = "Deep-Learning-Journey-" 

# 2. Identity batana (Zaroori Step)
# !git config --global user.email "hifza.ai.student@gmail.com"
# !git config --global user.name "Hifza-AI"

# 3. Purana folder saaf karke fresh clone karna
if os.path.exists(repo_name):
    shutil.rmtree(repo_name)

repo_url = f"https://{username}:{token}@github.com/{username}/{repo_name}.git"
# !git clone {repo_url}
# %cd {repo_name}

# 4. Notebook file ko dhoond kar copy karna
# Hum sab se pehle check karenge ke file kahan hai
# !cp /kaggle/working/__notebook_source__.ipynb ./Day_2_Neural_Network.ipynb || cp ../__notebook_source__.ipynb ./Day_2_Neural_Network.ipynb

# 5. Push it!
# !git add .
# !git commit -m "Day 2: Final Success Upload 🚀"
# !git push
# Out:
# Cloning into 'Deep-Learning-Journey-'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 5 (delta 0), reused 2 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (5/5), done.
# /kaggle/working/Deep-Learning-Journey-/Deep-Learning-Journey-
# cp: cannot stat '/kaggle/working/__notebook_source__.ipynb': No such file or directory
# cp: cannot stat '../__notebook_source__.ipynb': No such file or directory
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %%
import os
import shutil
from kaggle_secrets import UserSecretsClient

# 1. Setup
user_secrets = UserSecretsClient()
token = user_secrets.get_secret("GITHUB_TOKEN")
username = user_secrets.get_secret("GITHUB_USERNAME")
repo_name = "Deep-Learning-Journey-" 

# 2. Identity config
# !git config --global user.email "hifza.ai.student@gmail.com"
# !git config --global user.name "Hifza-AI"

# 3. Purana "Submodule" hatao (Ye zaroori step hai)
# Hum cache saaf karenge taake folder sahi ho jaye
# !git rm -r --cached {repo_name} || echo "Already clean"

# 4. Fresh Start
if os.path.exists(repo_name):
    shutil.rmtree(repo_name)

repo_url = f"https://{username}:{token}@github.com/{username}/{repo_name}.git"
# !git clone {repo_url}
# %cd {repo_name}

# 5. File copy karo (Sahi raste se)
# !cp /kaggle/working/__notebook_source__.ipynb ./Day_2_Neural_Network.ipynb

# 6. Push
# !git add .
# !git commit -m "Day 2: Final File Fix 🚀"
# !git push
# Out:
# rm 'Deep-Learning-Journey-'
# Cloning into 'Deep-Learning-Journey-'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 5 (delta 0), reused 2 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (5/5), done.
# /kaggle/working/Deep-Learning-Journey-/Deep-Learning-Journey-/Deep-Learning-Journey-
# cp: cannot stat '/kaggle/working/__notebook_source__.ipynb': No such file or directory
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %%
import os
import shutil
from kaggle_secrets import UserSecretsClient

# 1. Setup
user_secrets = UserSecretsClient()
token = user_secrets.get_secret("GITHUB_TOKEN")
username = user_secrets.get_secret("GITHUB_USERNAME")
repo_name = "Deep-Learning-Journey-" 

# 2. Cleanup (Purana galat record saaf karne ke liye)
# !git rm -r --cached {repo_name} || echo "Pehle se saaf hai"
if os.path.exists(repo_name):
    shutil.rmtree(repo_name)

# 3. Fresh Clone
repo_url = f"https://{username}:{token}@github.com/{username}/{repo_name}.git"
# !git clone {repo_url}
# %cd {repo_name}

# 4. File Copy (Check karke sahi file uthayega)
if os.path.exists('/kaggle/working/__notebook_source__.ipynb'):
    # !cp /kaggle/working/__notebook_source__.ipynb ./Day_2_Notebook.ipynb
else:
    # !cp ../notebook.ipynb ./Day_2_Notebook.ipynb || echo "Manually save version first"

# 5. Push it!
# !git add .
# !git commit -m "Day 2: Final Working File Upload 🚀"
# !git push
# Out:
# rm 'Deep-Learning-Journey-'
# Cloning into 'Deep-Learning-Journey-'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (4/4), done.
# Receiving objects: 100% (5/5), done.
# remote: Total 5 (delta 0), reused 2 (delta 0), pack-reused 0 (from 0)
# /kaggle/working/Deep-Learning-Journey-/Deep-Learning-Journey-/Deep-Learning-Journey-/Deep-Learning-Journey-
# cp: cannot stat '../notebook.ipynb': No such file or directory
# Manually save version first
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %%
import os
import shutil
from kaggle_secrets import UserSecretsClient

# 1. Setup
user_secrets = UserSecretsClient()
token = user_secrets.get_secret("GITHUB_TOKEN")
username = user_secrets.get_secret("GITHUB_USERNAME")
repo_name = "Deep-Learning-Journey-" 

# 2. Cleanup (Purana galat record saaf karne ke liye)
# !git rm -r --cached {repo_name} || echo "Pehle se saaf hai"
if os.path.exists(repo_name):
    shutil.rmtree(repo_name)

# 3. Fresh Clone
repo_url = f"https://{username}:{token}@github.com/{username}/{repo_name}.git"
# !git clone {repo_url}
# %cd {repo_name}

# 4. File Copy (Check karke sahi file uthayega)
if os.path.exists('/kaggle/working/__notebook_source__.ipynb'):
    # !cp /kaggle/working/__notebook_source__.ipynb ./Day_2_Notebook.ipynb
else:
    # !cp ../notebook.ipynb ./Day_2_Notebook.ipynb || echo "Manually save version first"

# 5. Push it!
# !git add .
# !git commit -m "Day 2: Final Working File Upload 🚀"
# !git push
# Out:
# rm 'Deep-Learning-Journey-'
# Cloning into 'Deep-Learning-Journey-'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 5 (delta 0), reused 2 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (5/5), done.
# /kaggle/working/Deep-Learning-Journey-/Deep-Learning-Journey-/Deep-Learning-Journey-/Deep-Learning-Journey-/Deep-Learning-Journey-
# cp: cannot stat '../notebook.ipynb': No such file or directory
# Manually save version first
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %%
import os
import shutil
from kaggle_secrets import UserSecretsClient

# 1. Secrets aur Setup
user_secrets = UserSecretsClient()
token = user_secrets.get_secret("GITHUB_TOKEN")
username = user_secrets.get_secret("GITHUB_USERNAME")
repo_name = "Deep-Learning-Journey-" 

# Identity fix
# !git config --global user.email "hifza.ai.student@gmail.com"
# !git config --global user.name "Hifza-AI"

# 2. Purana record saaf karna (Crucial Step)
# !git rm -r --cached {repo_name} || echo "Already clean"
if os.path.exists(repo_name):
    shutil.rmtree(repo_name)

# 3. Fresh Clone
repo_url = f"https://{username}:{token}@github.com/{username}/{repo_name}.git"
# !git clone {repo_url}

# 4. File dhoond kar copy karna (The Master Logic)
# Ye command sari files check karegi aur notebook ko utha legi
import glob
files = glob.glob("/kaggle/working/*.ipynb") + glob.glob("/kaggle/working/../*.ipynb")
if files:
    source_file = files[0]
    shutil.copy(source_file, f"{repo_name}/Deep_Learning_Day_1_Neural_Networks.ipynb")
    print(f"✅ Success! File copied from {source_file}")
else:
    print("❌ Error: File nahi mili. Ek baar 'Save Version' par click karein.")

# 5. Push to GitHub
# %cd {repo_name}
# !git add .
# !git commit -m "Day 2: Final Verified Upload 🚀"
# !git push
# Out:
# rm 'Deep-Learning-Journey-'
# Cloning into 'Deep-Learning-Journey-'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 5 (delta 0), reused 2 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (5/5), done.
# ❌ Error: File nahi mili. Ek baar 'Save Version' par click karein.
# /kaggle/working/Deep-Learning-Journey-/Deep-Learning-Journey-/Deep-Learning-Journey-/Deep-Learning-Journey-/Deep-Learning-Journey-/Deep-Learning-Journey-/Deep-Learning-Journey-/Deep-Learning-Journey-
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date
