# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np

# %%
import os, shutil, glob
from kaggle_secrets import UserSecretsClient

# 1. Credentials
user_secrets = UserSecretsClient()
token = user_secrets.get_secret("GITHUB_TOKEN")
username = user_secrets.get_secret("GITHUB_USERNAME")
repo_name = "Deep-learning-journey-" 

# 2. Reset & Clone
os.chdir('/kaggle/working')
if os.path.exists(repo_name):
    shutil.rmtree(repo_name)

# Git Config
# !git config --global user.email "hifza.ai.student@gmail.com"
# !git config --global user.name "{username}"

# Clone the repo
repo_url = f"https://{username}:{token}@github.com/{username}/{repo_name}.git"
print("🚀 Connecting to GitHub...")
# !git clone {repo_url}

# 3. SMART SEARCH (Latest Notebook Dhoondna)
# Hum saari .ipynb files dhoondte hain jo repo folder se bahar hain
all_notebooks = glob.glob("/kaggle/working/*.ipynb")
valid_notebooks = [f for f in all_notebooks if repo_name not in f and ".ipynb_checkpoints" not in f]

if valid_notebooks:
    # Sab se latest notebook (jo tumne abhi save ki hai)
    latest_file = max(valid_notebooks, key=os.path.getmtime)
    print(f"✅ MIL GAYI! Target: {latest_file}")
    
    # GitHub ke liye naya naam
    github_filename = "Day_4_Forward_Propagation_Final.ipynb"
    shutil.copy(latest_file, f"{repo_name}/{github_filename}")
    
    # 4. Push to GitHub
    os.chdir(repo_name)
    # !git add .
    # !git commit -m "Day 4: Environment Masla Resolved! 🏆"
    # !git push
    print(f"\n🔥 JEET GAYI HO HIFZA! GitHub par '{github_filename}' check karo.")
else:
    # Agar phir bhi na miley, toh ek baar manual check
    print("❌ Abhi bhi file nahi mili. Kaggle session ko refresh hone mein shayad time lag raha hai.")
    print("Ek baar cell mein '!ls /kaggle/working' likh kar output dekho.")
# Out:
# 🚀 Connecting to GitHub...
# Cloning into 'Deep-learning-journey-'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 15 (delta 5), reused 6 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), 42.14 KiB | 3.24 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# ❌ Abhi bhi file nahi mili. Kaggle session ko refresh hone mein shayad time lag raha hai.
# Ek baar cell mein '!ls /kaggle/working' likh kar output dekho.

# %%
# !ls /kaggle/working
# Out:
# Deep-learning-journey-

# %%
import os, shutil, glob
from kaggle_secrets import UserSecretsClient

# 1. Credentials
user_secrets = UserSecretsClient()
token = user_secrets.get_secret("GITHUB_TOKEN")
username = user_secrets.get_secret("GITHUB_USERNAME")
repo_name = "Deep-learning-journey-" 

# 2. Reset & Clone
os.chdir('/kaggle/working')
if os.path.exists(repo_name):
    shutil.rmtree(repo_name)

# !git config --global user.email "hifza.ai.student@gmail.com"
# !git config --global user.name "{username}"

repo_url = f"https://{username}:{token}@github.com/{username}/{repo_name}.git"
# !git clone {repo_url}

# 3. ULTIMATE SEARCH (Poore system ki talashi)
# Hum saari .ipynb files dhoondte hain jo Kaggle ke kisi bhi kone mein hain
all_files = glob.glob("/kaggle/**/*.ipynb", recursive=True)
# Apni repo folder wali files ko nikaal do
valid_notebooks = [f for f in all_files if repo_name not in f and "checkpoint" not in f]

if valid_notebooks:
    # Sab se latest file uthao
    latest_nb = max(valid_notebooks, key=os.path.getmtime)
    print(f"✅ MIL GAYI! Location: {latest_nb}")
    
    # GitHub ke liye copy karo
    shutil.copy(latest_nb, f"{repo_name}/Deep_Learning_Class_4.ipynb")
    
    # 4. Push to GitHub
    os.chdir(repo_name)
    # !git add .
    # !git commit -m "Day 4: Environment Defeated! Victory is Ours! 🏆"
    # !git push
    print(f"\n🔥 MUBARAK HO HIFZA! GitHub par file pohnch gayi hai.")
else:
    print("❌ Yaar, Kaggle ne file bohot gehrai mein chupa di hai.")
    print("Aakhri rasta: Manual download & upload karo aur is zaleel environment ko hara do!")
# Out:
# Cloning into 'Deep-learning-journey-'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 15 (delta 5), reused 6 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), 42.14 KiB | 3.24 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# ❌ Yaar, Kaggle ne file bohot gehrai mein chupa di hai.
# Aakhri rasta: Manual download & upload karo aur is zaleel environment ko hara do!
